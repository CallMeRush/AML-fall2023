# %% [markdown]
# # Free space

# %%
print("free space")

# %% [markdown]
# # Imports

# %%
import pandas as pd
import pywt

# %% [markdown]
# # Data import

# %%
X_train_df = pd.read_csv('data/X_train.csv', index_col='id')
y_train_df = pd.read_csv('data/y_train.csv', index_col='id')
X_test_df = pd.read_csv('data/X_test.csv', index_col='id')

# %% [markdown]
# ### Drop trailing NaN

# %%
def drop_trailing_na(df: pd.DataFrame):
    return [df.loc[i].dropna().to_numpy() for i in range(df.shape[0])]

X_train = drop_trailing_na(X_train_df)
y_train = y_train_df['y'].to_numpy()
X_test = drop_trailing_na(X_test_df)

# %%
print(X_train)
# Out:
# [array([-13.,  -9.,  -6., ...,  60.,  74.,  91.]), array([-34., 110., 249., ...,   1.,  -6., -12.]), array([-34., -36., -37., ...,  26.,  26.,  26.]), array([ 292.,  298.,  303., ..., -187., -187., -187.]), array([157., 179., 195., ...,  21.,  24.,  29.]), array([-377., -364., -352., ...,   -8.,    0.,    6.]), array([ 19.,  36.,  51., ..., -23., -36., -45.]), array([-363., -291., -230., ...,   77.,   78.,   79.]), array([608., 778., 865., ..., -42., -40., -39.]), array([-69., -72., -75., ...,  69.,  59.,  50.]), array([  8.,   7.,   6., ..., -52., -49., -22.]), array([43., 43., 42., ..., 90., 84., 78.]), array([187., 193., 200., ...,  53., 108., 189.]), array([ 795.,  767.,  744., ..., -197., -200., -203.]), array([399., 380., 320., ..., -18., -21., -24.]), array([-22., -23., -23., ...,   4.,   4.,   4.]), array([25., 24., 24., ..., 15., 15., 14.]), array([-90., -80., -65., ..., -38., -34., -30.]), array([-148., -159., -169., ..., -184., -192., -202.]), array([-549., -531., -519., .
# ...

# %% [markdown]
# # Length adjustments

# %% [markdown]
# # Noise filtration
